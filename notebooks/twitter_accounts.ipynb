# %% [markdown]
# Accessed using: https://github.com/prinsss/twitter-web-exporter?tab=readme-ov-file

# %%
import pandas as pd

# %%
pd.read_csv('twitter-Followers-1737895856914.csv')
# Out:
#                      id    screen_name                                 name  \
# 0   1025247075351576576         IOYAWU                                 TaTa
# 1   1115049654138355714     0xbobchien                             Bob C. ✨
# 2   1142536749324939264     Crypto_koH                                  koH
# 3             116317265         0xACDI                                Ale Ω
# 4   1179086771763572736   ygg_anderson              YGG ⟠ linuxiscool.eth 🦇
# ..                  ...            ...                                  ...
# 71            820726998  BitConductor_                              Lautaro
# 72             82128102          ecfk0                           Eduardo CF
# 73            859928407  Cristhianrg12                  Cristhian rodriguez
# 74              8705962         owocki        Kev.Ξth’s learning HOW TO DAO
# 75   905265497221980160       papa_raw  pat ✨ is collecting green tokens 🔍🟢
#
#                                           description  \
# ...

# %%
pd.read_csv('twitter-Following-1737895867108.csv')
# Out:
#                      id      screen_name                                 name  \
# 0   1012848315744993280        RealRossU                        Ross Ulbricht
# 1              11004662              wor                         Will Ruddick
# 2   1179086771763572736     ygg_anderson              YGG ⟠ linuxiscool.eth 🦇
# 3   1295028541139177482     eulerfinance                       Euler Labs🛢️🇬🇧
# 4   1304609819504984067    VenusProtocol                       Venus Protocol
# 5   1338433114352332801           0xVEER                                 VEER
# 6   1349919977210462212           0xbury                            0xbury 🇺🇸
# 7   1365173420019781636   tonyplasencia3                               t◎ny p
# 8             138108708     BenGoldsmith                        Ben Goldsmith
# 9   1426732252768182281     notthreadguy                          threadguy 👑
# 10  1427669800982024202      neppahtitel                      neppah ti tel ♡
# ...
